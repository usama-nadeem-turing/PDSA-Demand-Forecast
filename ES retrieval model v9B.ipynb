# %% [markdown]
# ### Basic setup
#
# - Imports
# - Basic skill map
# - Features

# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import ast
import pickle
import sys
from tqdm.auto import tqdm
import os
tqdm.pandas()
from pathlib import Path
import requests
import json
import config

import time


warnings.filterwarnings("ignore")

# %%
def get_challenges():
    """
    returns a dict mapping skills to challenges
    """
    skill_det = pd.io.gbq.read_gbq(
    f"""

        SELECT
            mjs.skill_id,
            bas.skill_name,
            ARRAY_AGG(DISTINCT msc.challenge_id IGNORE NULLS) AS challenge_ids,
        FROM
            (
            SELECT DISTINCT skill_id FROM `turing-230020.raw.tpm_developer_skill` 
            UNION DISTINCT 
            SELECT DISTINCT skill_id FROM `turing-230020.raw.ms2_job_skill` 
            )mjs
        LEFT JOIN
            `raw.ms2_skill_challenges` msc
        ON
            mjs.skill_id = msc.skill_id
        LEFT JOIN
            `raw.base_all_skills_v4` bas
        ON
            mjs.skill_id = bas.id
        GROUP BY
        1,2


    """,project_id='turing-230020')
    
    challenge_map = {}
    name_map = {}
    for skill in skill_det.skill_id.values:
        challenge_map[skill] = skill_det[skill_det.skill_id == skill].challenge_ids.values[0]
        name_map[skill] = skill_det[skill_det.skill_id == skill].skill_name.values[0]

    return challenge_map, name_map

# %%
challenge_map, name_map = get_challenges()

# %% [markdown]
# ### Active Jobs

# %% [markdown]
# ### Skills of Active Jobs

# %%
# must have skills as a list of lists
job_skills = pd.io.gbq.read_gbq(
f"""


WITH forcasted_tuples AS 
(  
  SELECT 
    job_id, skill_name, id AS skill_id
  FROM
  (
    SELECT 
    job_id, 
    CASE 
      WHEN (skill_name = ' Laravel') THEN 'Laravel'
      WHEN (skill_name = 'Android: Kotlin') THEN 'Android/Kotlin'
      ELSE skill_name
    END AS skill_name
    FROM `turing-230020.product_ds_supply.forecasted_tuples`, UNNEST(SPLIT(Skill_Tuple, '|'))skill_name 
  ) LEFT JOIN `turing-230020.raw.base_all_skills_v4` USING(skill_name)
)


  SELECT
    job_id,
    `matchingmetrics`.structurize_skills(TO_JSON_STRING(ARRAY_AGG(DISTINCT skill_id
        ORDER BY
          skill_id))) AS skills
  FROM
    forcasted_tuples
  GROUP BY
    job_id 
"""
,project_id='turing-230020')
#  jsi.job_id in {tuple(active_jobs.job_id.unique())}
job_skills
# Out:
#     job_id                    skills
# 0    13009        [[93],[114],[165]]
# 1    14030       [[120],[125],[158]]
# 2    13833  [[65],[114],[557],[558]]
# 3    14448      [[120],[387],[2031]]
# 4    11698                  [[2117]]
# ..     ...                       ...
# 192  11487                  [[2031]]
# 193  13580                   [[268]]
# 194  12885                  [[1938]]
# 195  11007                   [[433]]
# 196  10370                    [[54]]
#
# [197 rows x 2 columns]

# %%
skill_id_dict = {
      108: [108, 97, 448]
    , 567: [567, 2068]
    , 568: [568, 277]
    , 65: [65, 221]
    , 71: [1157, 71]
    , 257: [257, 443, 444, 467, 762, 189, 2140]
    , 70: [70, 60]
    , 351: [351, 394, 2084]
    , 541: [541, 204]
    , 1547: [1547, 460, 2114]
    , 1598: [1598, 483, 1571, 41]
    , 686: [686, 348, 347]
    , 25: [25, 2050]
    , 554: [554, 555]
    , 2096: [2096, 26]
    , 387: [387, 308]
    , 264: [264, 1408]
    , 358: [358, 1928, 2087]
    , 1821: [1821, 2061]
    , 114: [114, 86, 113, 2097]
    , 1938: [1696, 1123, 2150, 614]
    , 1025: [1025, 1389]
    , 127: [127, 162, 327]
    , 301: [301, 1991]
    , 1315: [1315, 464, 1675, 1676, 1258]
    , 2: [2, 3]
    , 2020: [2020, 401, 680]
    , 400: [400, 2032]
    , 223: [223, 1647]
    , 20: [20, 710, 1466]
    , 174: [174, 128]
    , 258: [258, 73, 1250]
    , 1286: [1286, 33, 1063, 812]
    , 1420: [1420, 1470]
    , 433: [433, 2133, 1827]
    , 449: [449, 1465]
    , 29: [29, 1688]
    , 166: [166, 173]
    , 107: [107, 309]
    , 125: [125, 1615, 111, 1059, 946, 328]
    , 2055: [2055, 425]
    , 93: [93, 598]
    , 2094: [2094, 256, 678, 2091, 2092, 1349, 1964, 397, 1300]
    , 2036: [2036, 1873, 1397, 2154, 1855]
    , 1939: [1939, 706, 1822, 153, 707, 1830]
}

job_skills['original_skills'] = job_skills['skills'] 

skills = []
for _, row in job_skills.iterrows():
    job_skill = []
    for skill in row['skills'].split(','):
        if skill.strip('][').split(', ')[0] != 'null':
            temp = int(skill.strip('][').split(', ')[0])
            if temp in skill_id_dict.keys():
                job_skill.append(skill_id_dict[temp])
            else:
                job_skill.append([temp])
    skills.append(job_skill)

job_skills['skills'] = skills

job_skills['skills'] = job_skills['skills'].astype(str)
job_skills
# Out:
#     job_id                                            skills  \
# 0    13009          [[93, 598], [114, 86, 113, 2097], [165]]
# 1    14030  [[120], [125, 1615, 111, 1059, 946, 328], [158]]
# 2    13833   [[65, 221], [114, 86, 113, 2097], [557], [558]]
# 3    14448                       [[120], [387, 308], [2031]]
# 4    11698                                          [[2117]]
# ..     ...                                               ...
# 192  11487                                          [[2031]]
# 193  13580                                           [[268]]
# 194  12885                         [[1696, 1123, 2150, 614]]
# 195  11007                               [[433, 2133, 1827]]
# 196  10370                                            [[54]]
#
#               original_skills
# 0          [[93],[114],[165]]
# 1         [[120],[125],[158]]
# 2    [[65],[114],[557],[558]]
# 3        [[120],[387],[2031]]
# 4                    [[2117]]
# ..                        ...
# 192                  [[2031]]
# 193                   [[268]]
# 194                  [[1938]]
# 195                   [[433]]
# 196                    [[54]]
#
# [197 rows x 3 columns]

# %%
job_skills.skills = job_skills.skills.map(ast.literal_eval)
job_skills['num_skills'] = job_skills.skills.map(len)
job_skills['g_skills'] = job_skills.skills.apply(lambda r: [[{"skillId":s,'keyword':name_map[s]} for s in skills] for skills in sorted(r)])
job_skills['keywords'] = job_skills.skills.apply(lambda r: [name_map[s] for skill in r for s in skill])
job_skills['skill_comb'] = job_skills.g_skills.apply(lambda r: str(r))

job_skills_dict = {job['job_id']:job['skills'] for id,job in job_skills.iterrows()}
job_skills
# Out:
#     job_id                                            skills  \
# 0    13009          [[93, 598], [114, 86, 113, 2097], [165]]
# 1    14030  [[120], [125, 1615, 111, 1059, 946, 328], [158]]
# 2    13833   [[65, 221], [114, 86, 113, 2097], [557], [558]]
# 3    14448                       [[120], [387, 308], [2031]]
# 4    11698                                          [[2117]]
# ..     ...                                               ...
# 192  11487                                          [[2031]]
# 193  13580                                           [[268]]
# 194  12885                         [[1696, 1123, 2150, 614]]
# 195  11007                               [[433, 2133, 1827]]
# 196  10370                                            [[54]]
#
#               original_skills  num_skills  \
# 0          [[93],[114],[165]]           3
# 1         [[120],[125],[158]]           3
# 2    [[65],[114],[557],[558]]           4
# 3        [[120],[387],[2031]]           3
# 4                    [[2117]]           1
# ..                        ...         ...
# 192                  [[2031]]           1
# 193                   [[268]]           1
# 194                  [[1938]]           1
# 195                   [[433]]           1
# 196                    [[54]]           1
#
#                                               g_skills  \
# 0    [[{'skillId': 93, 'keyword': 'JavaScript'}, {'...
# 1    [[{'skillId': 120, 'keyword': 'Node.js'}], [{'...
# 2    [[{'skillId': 65, 'keyword': 'Apache Spark'}, ...
# 3    [[{'skillId': 120, 'keyword': 'Node.js'}], [{'...
# 4          [[{'skillId': 2117, 'keyword': 'Shopify'}]]
# ..                                                 ...
# 192          [[{'skillId': 2031, 'keyword': 'React'}]]
# 193  [[{'skillId': 268, 'keyword': 'Machine Learnin...
# 194  [[{'skillId': 1696, 'keyword': 'User-Centered ...
# 195  [[{'skillId': 433, 'keyword': 'AWS'}, {'skillI...
# 196           [[{'skillId': 54, 'keyword': 'DevOps'}]]
#
#                                               keywords  \
# 0    [JavaScript, Javascript ES6, SQL, PostgreSQL, ...
# 1    [Node.js, API Design, API Integrations  , REST...
# 2    [Apache Spark, Spark, SQL, PostgreSQL, MySQL, ...
# 3                        [Node.js, HTML, HTML5, React]
# 4                                            [Shopify]
# ..                                                 ...
# 192                                            [React]
# 193                                 [Machine Learning]
# 194  [User-Centered Design, UI Design, webflow, Figma]
# 195          [AWS, AWS Operations, AWS Administration]
# 196                                           [DevOps]
#
#                                             skill_comb
# 0    [[{'skillId': 93, 'keyword': 'JavaScript'}, {'...
# 1    [[{'skillId': 120, 'keyword': 'Node.js'}], [{'...
# 2    [[{'skillId': 65, 'keyword': 'Apache Spark'}, ...
# 3    [[{'skillId': 120, 'keyword': 'Node.js'}], [{'...
# 4          [[{'skillId': 2117, 'keyword': 'Shopify'}]]
# ..                                                 ...
# 192          [[{'skillId': 2031, 'keyword': 'React'}]]
# 193  [[{'skillId': 268, 'keyword': 'Machine Learnin...
# 194  [[{'skillId': 1696, 'keyword': 'User-Centered ...
# 195  [[{'skillId': 433, 'keyword': 'AWS'}, {'skillI...
# 196           [[{'skillId': 54, 'keyword': 'DevOps'}]]
#
# [197 rows x 7 columns]

# %% [markdown]
# ### Must-Have Skill Retrieval
#
# Replication of DE pipeline.

# %%
tqdm.monitor_interval = 0

results = pd.DataFrame({'job_id':[],'userId':[],'score':[]})
resp = ''
for id,job in tqdm(job_skills.iterrows(),total=len(job_skills)):
    with requests.Session() as s:
        payload = json.load(open('api_payload_current_retrieval.json', 'r'))

        payload['skillKeywordSearch']['mustHave'] = job['g_skills']

        payload['searchAnywhereParameters']['mustHaveWords'] = job['keywords']
        payload['skillKeywordSearch']['mustHave'] = job['g_skills']
        payload['jobId'] = job['job_id']#.astype(str)


        json_payload = json.dumps(payload)
        content_length = str(len(json_payload))

        headers = {
            'Content-Type': 'application/json',
            'Content-Length': content_length,
            'authorization': config.bearer_token
        }

        resp = s.post(config.url, json_payload, headers = headers)
        try:
            resp_df = pd.DataFrame(json.loads(json.dumps(resp.json()['developers'])))
            resp_df['job_id'] = job['job_id']
            results = results.append(resp_df)
            print(f"job: {job['job_id']} : Done")
        except Exception as e:
            print(e)
            print(f"job: {job['job_id']} : Error - {resp.status_code}: {resp.text}")
            continue
results.shape
# Out:
#   0%|          | 0/197 [00:00<?, ?it/s]
# job: 13009 : Done
# job: 14030 : Done
# job: 13833 : Done
# job: 14448 : Done
# job: 11698 : Done
# job: 10507 : Done
# job: 11373 : Done
# 'developers'
# job: 10626 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T20:29:57.048Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"a1086879-5d00-4f09-a989-28f79cf55994\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"89c02189-d507-4ece-9108-fd7a6db195a4\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13},{\"rankingUuid\":\"79f84306-9bfb-4f0f-8255-79eccdd26142\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"c081732a-e160-4dfd-a001-ef687913ddee\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13},{\"rankingUuid\":\"c049a68f-7e0e-4d48-a7be-4835c2d0bdbb\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"26580203-c80f-4bee-b314-32de861e278c\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13},{\"rankingUuid\":\"fd352abb-0bcb-4c85-afd3-69c67989ced4\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13},{\"rankingUuid\":\"3da7460b-defd-4722-9135-eece005f3e6b\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"c51a1916-9a14-4001-ad84-0bf46e333fe8\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"5462524a-31eb-4f8c-bcf7-11b9b6924723\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4}]"}
# job: 10939 : Done
# 'developers'
# job: 11089 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T20:31:51.308Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"9c0efe19-d5a8-4b7e-8228-273fd4cb39e3\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"2d22dd00-f3e9-4ad7-92d2-1eb352842f52\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"88cb5e20-138a-4530-bc16-24413f95ce3f\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4}]"}
# job: 10300 : Done
# job: 12226 : Done
# job: 11778 : Done
# job: 11668 : Done
# job: 13166 : Done
# job: 12815 : Done
# job: 12231 : Done
# job: 12752 : Done
# job: 10994 : Done
# job: 11205 : Done
# job: 11448 : Done
# job: 13632 : Done
# job: 13131 : Done
# job: 10938 : Done
# job: 13554 : Done
# job: 10554 : Done
# job: 14195 : Done
# job: 12621 : Done
# job: 13059 : Done
# job: 12828 : Done
# job: 13104 : Done
# job: 11416 : Done
# job: 11472 : Done
# job: 12486 : Done
# job: 10313 : Done
# job: 13504 : Done
# job: 10871 : Done
# job: 13666 : Done
# job: 13512 : Done
# job: 12237 : Done
# job: 12913 : Done
# job: 13660 : Done
# job: 12203 : Done
# job: 13016 : Done
# job: 12630 : Done
# job: 11809 : Done
# job: 10654 : Done
# 'developers'
# job: 11256 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T20:41:15.962Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"82bdc282-f23d-42d7-88ca-e9d2607ae0cd\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"38f233e4-bae2-4c78-a07a-424f15ba1259\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"af441fa9-0a12-4632-9d7c-fc80b0e3eb28\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"60a069f9-95e0-4923-95df-391f2d63c93c\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"d531b078-6e51-4d63-a22f-917a406f4824\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"0243c0e5-5bcf-4816-94a7-a5e1abc9ef0c\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"5cbfa968-a7fc-490c-84fe-65b9af1c48de\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4}]"}
# job: 13719 : Done
# job: 14251 : Done
# job: 12306 : Done
# job: 13372 : Done
# job: 13276 : Done
# 'developers'
# job: 13234 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T20:44:49.771Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"0211945f-2b3c-4c49-a586-c9e62f895984\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"2ff688df-e190-401f-9b7f-1968ee9cf8ea\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"ca6563b4-6465-42ad-8fc8-afdc9007ca02\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13},{\"rankingUuid\":\"885bfb40-33c2-4380-af4f-eb234510131e\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"c6e1cf1d-1fe9-43de-a27d-807315796bc1\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13},{\"rankingUuid\":\"3a6528a4-29e4-4e1d-8455-8160269debb9\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13}]"}
# job: 10613 : Done
# job: 13006 : Done
# job: 13676 : Done
# job: 12485 : Done
# 'developers'
# job: 13174 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T20:46:54.154Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"2a96f65b-0a39-415c-9063-29dc0a455ba1\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"d80c7875-515c-4661-b3a3-6484109dc5b3\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"25977a2f-03b2-4c97-b45d-a8ca3aaef538\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"43d84957-1f9e-49a7-be58-17efce38d6ca\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"21fe7f92-a05c-4ecb-92e1-763b10c00e47\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"b881db58-a661-45f0-9335-b5d75383d524\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4}]"}
# job: 12075 : Done
# job: 14482 : Done
# job: 11060 : Done
# job: 12522 : Done
# job: 14196 : Done
# job: 10385 : Done
# job: 12980 : Done
# job: 12745 : Done
# job: 11990 : Done
# 'developers'
# job: 11662 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T20:52:32.989Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"9649449c-aca6-4cc1-8347-cbfbb5cdbf5b\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13},{\"rankingUuid\":\"c86a3714-7800-45a0-baae-b567b19e64d8\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13},{\"rankingUuid\":\"147cff32-6e17-45d2-811f-6aad55300aa8\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"e8d113d3-1288-455c-91fd-49a06bf01c49\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"da4813c7-b170-4601-8bc0-a4a56a2f972d\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4}]"}
# job: 10495 : Done
# job: 11747 : Done
# job: 13628 : Done
# job: 10325 : Done
# job: 10824 : Done
# job: 12805 : Done
# job: 12526 : Done
# job: 10893 : Done
# job: 11378 : Done
# job: 13736 : Done
# job: 13189 : Done
# job: 13013 : Done
# job: 10876 : Done
# job: 12801 : Done
# job: 12529 : Done
# job: 13947 : Done
# job: 12067 : Done
# job: 13034 : Done
# job: 12610 : Done
# job: 10899 : Done
# 'developers'
# job: 10739 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T20:58:35.231Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"9da0ccaf-05f7-451f-86dc-89d40328809f\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"9917239d-3316-4a88-b9d0-d3e035ecf3de\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"777f41bb-7319-4fcc-baf4-fe38eb971c4e\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"e1e39fe0-d734-4055-b6d3-e0edde56c2af\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"8a200d1c-e9c5-4582-b33c-aa0f0c252b69\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"99a6eb78-aa59-4095-a1f5-d328d17b92d9\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"ee00dd7a-ab7a-4c0c-a366-7f43b6c6d8bc\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"6129e9c0-9bbc-4800-8369-e7d10da1bf8d\",\"message\":\"13 INTERNAL: {\\\"detail\\\":\\\"Feature Service Error\\\"}\",\"grpc_code\":13}]"}
# job: 10582 : Done
# job: 13125 : Done
# job: 12755 : Done
# job: 11842 : Done
# job: 10478 : Done
# job: 13651 : Done
# job: 10364 : Done
# job: 12135 : Done
# job: 10764 : Done
# job: 12625 : Done
# job: 12632 : Done
# job: 12780 : Done
# job: 10264 : Done
# job: 12332 : Done
# job: 13509 : Done
# job: 13967 : Done
# job: 13386 : Done
# job: 13564 : Done
# job: 11516 : Done
# job: 13500 : Done
# job: 10845 : Done
# job: 13734 : Done
# job: 12036 : Done
# job: 12104 : Done
# 'developers'
# job: 10375 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T21:06:56.907Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"a9b99579-b021-40d6-8b02-c610dfe88e7e\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"9023204d-593f-46a3-bd81-d1623554600f\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"3d2ec098-57d2-4406-8700-28bbcd7c4ba6\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"6ca069c3-bb79-4dab-a4bb-555e41ff4e92\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"750426cd-2e96-4b44-ba82-5575cd737257\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"545bd2d8-e054-4c0d-85e7-6ae037f742dd\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"11681425-3c6e-4808-9199-d206d9eca7fe\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"051a4e77-86e5-4a87-a1bb-ce191123d4ad\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4}]"}
# job: 12230 : Done
# job: 13574 : Done
# job: 13577 : Done
# job: 13661 : Done
# job: 11292 : Done
# job: 10870 : Done
# job: 10323 : Done
# job: 13943 : Done
# job: 10782 : Done
# job: 12873 : Done
# job: 13686 : Done
# job: 13618 : Done
# job: 10356 : Done
# job: 12884 : Done
# job: 10562 : Done
# job: 13683 : Done
# job: 11301 : Done
# job: 10483 : Done
# job: 11380 : Done
# job: 11366 : Done
# job: 10881 : Done
# job: 12776 : Done
# job: 13556 : Done
# job: 10548 : Done
# job: 10711 : Done
# job: 12471 : Done
# job: 10977 : Done
# job: 12954 : Done
# job: 12069 : Done
# job: 13614 : Done
# job: 10393 : Done
# job: 12478 : Done
# job: 11167 : Done
# job: 10366 : Done
# job: 10646 : Done
# job: 14447 : Done
# job: 12414 : Done
# job: 13687 : Done
# job: 10329 : Done
# job: 12723 : Done
# job: 10763 : Done
# job: 12979 : Done
# job: 11105 : Done
# job: 12985 : Done
# job: 10840 : Done
# job: 12936 : Done
# job: 12022 : Done
# job: 13678 : Done
# job: 10510 : Done
# job: 11387 : Done
# job: 11740 : Done
# job: 12007 : Done
# job: 10249 : Done
# 'developers'
# job: 11290 : Error - 500: {"statusCode":500,"timestamp":"2023-06-27T21:26:20.326Z","path":"/api/search/developer/matching/","method":"POST","message":"[{\"rankingUuid\":\"436f4448-7431-4612-be74-5edc563d2d39\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"46907edf-c350-4eb8-a0ce-99b69dfdb6db\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"b1ca849d-be02-4943-80ae-dc5ac4155f29\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"5b859fd6-0a04-490b-80df-7c56755b89dd\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"c1489d62-b457-46c6-9eac-3a7a18c881ac\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4},{\"rankingUuid\":\"b95477ec-c1a6-4311-a3a3-58f4b7648921\",\"message\":\"4 DEADLINE_EXCEEDED: Took too long to respond when processing endpoint_id: 222140931229351936, deployed_model_id: 6722363514687586304\",\"grpc_code\":4}]"}
# job: 13562 : Done
# job: 11743 : Done
# job: 10464 : Done
# job: 12697 : Done
# job: 11087 : Done
# job: 11199 : Done
# job: 11151 : Done
# job: 11684 : Done
# job: 11117 : Done
# job: 10462 : Done
# job: 13374 : Done
# job: 12842 : Done
# job: 13204 : Done
# job: 12656 : Done
# job: 10546 : Done
# job: 10847 : Done
# job: 13521 : Done
# job: 14266 : Done
# job: 13124 : Done
# job: 14257 : Done
# job: 12838 : Done
# job: 12416 : Done
# job: 13117 : Done
# job: 11487 : Done
# job: 13580 : Done
# job: 12885 : Done
# job: 11007 : Done
# job: 10370 : Done
# (1127435, 3)

# %% [markdown]
# ### Merge conditions, add miscellaneous conditions

# %%
results['Extraction_Date'] = time.strftime("%Y-%m-%d", time.localtime())
results_f = results.reset_index()[['Extraction_Date', 'job_id','userId', 'score']]
results_f.rename(columns = {'score' : 'v9b_score', 'userId':'dev_id'}, inplace = True)
results_f['job_id'] = results_f['job_id'].astype(int)
results_f['dev_id'] = results_f['dev_id'].astype(int)
results_f['type'] = 'Forecasted'

# %%
import pandas_gbq
# Replace 'your_project_id', 'your_dataset_id', and 'your_table_id' with your actual values
project_id = 'turing-230020'
dataset_id = 'product_ds_supply'
table_id = 'forecasted_tuples_supply'

# Insert the DataFrame into the BigQuery table

pandas_gbq.to_gbq(results_f, f'{dataset_id}.{table_id}', project_id=project_id, if_exists='append')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 12520.31it/s]
